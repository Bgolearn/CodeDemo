# %%
pip install Bgolearn

# %% [markdown]
# `HomePage` : http://bgolearn.caobin.asia/
#
# Assign a function to compare the optimization efficiency across different utility functions.

# %%
import Bgolearn.BGOsampling as BGOS
import numpy as np
import pandas as pd

# Define the true function
def function(X):
    X = np.array(X)
    Y = 0.013 * X**4 - 0.25 * X**3 + 1.61 * X**2 - 4.1 * X + 8
    return Y

# defind the search space
vs = np.arange(0, 10.01, 0.01)

# Initialize Bgolearn
Bgolearn = BGOS.Bgolearn()

# Pass parameters to the function
Mymodel = Bgolearn.test(Ture_fun=function, Def_Domain=vs)

# Compare efficiency using different methods
Mymodel.Trail()
# Out:
#  ____                 _
# | __ )   __ _   ___  | |  ___   __ _  _ __  _ __
# |  _ \  / _` | / _ \ | | / _ \ / _` || '__|| '_ \
# | |_) || (_| || (_) || ||  __/| (_| || |   | | | |
# |____/  \__, | \___/ |_| \___| \__,_||_|   |_| |_|
#         |___/
#
# Bgolearn, Bin CAO, HKUST(GZ)
# URL : https://github.com/Bin-Cao/Bgolearn and https://bgolearn.netlify.app/
# Citation:
# Materials & Design : https://doi.org/10.1016/j.matdes.2024.112921
# NPJ Computational Materials : https://doi.org/10.1038/s41524-024-01243-4
# Executed on : 2024-09-18 13:39:29  | Have a great day.
# ...
#  test model is developed for evaluating the regression efficiency
# The internal model is instantiated with homogenous noise: 1e-05
# Evaluation is executed
# current optimal is : 3.4571690429300084
# The next datum recomended by Expected Improvement :
#  x =  0.63
# The predictions of Bgolearn are :
#  y =  4.098970605213108
# current optimal is : 3.4571690429300084
# The next datum recomended by Expected Improvement :
# ...

# %%
import Bgolearn.BGOsampling as BGOS
import numpy as np
import pandas as pd

# Define the true function
def function(X):
    X = np.array(X)
    Y = 0.013 * X**4 - 0.25 * X**3 + 1.61 * X**2 - 4.1 * X + 8
    return Y

# defind the search space
vs = np.arange(0, 10.01, 0.01)

# Initialize Bgolearn
Bgolearn = BGOS.Bgolearn()

# Pass parameters to the function
Mymodel = Bgolearn.test(Ture_fun=function, Def_Domain=vs)

# Compare efficiency using different methods
# Mymodel.Trail()
# https://bgolearn.netlify.app/bgolearn/
